# %%
## Loading up all essential libraries
import numpy as np
import pandas as pd
import spacy
import nltk
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set()
# Out:
# C:\Users\iman_\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
nlp = spacy.load('en_core_web_lg') ## Spacy's large vocabulary library

# %%
df = pd.read_csv('train.csv') ## loading up the dataset

# %%
df['message'][6] ## checking how the typical main feature column row looks like
# Out:
# 'RT @thenation: Mike Pence doesn’t believe in global warming or that smoking causes lung cancer. https://t.co/gvWYaauU8R'

# %%
df.head(20)
# Out:
#     sentiment                                            message  tweetid
# 0           1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1           1  It's not like we lack evidence of anthropogeni...   126103
# 2           2  RT @RawStory: Researchers say we have three ye...   698562
# 3           1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4           1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# 5           1  Worth a read whether you do or don't believe i...   425577
# 6           1  RT @thenation: Mike Pence doesn’t believe in g...   294933
# 7           1  RT @makeandmendlife: Six big things we can ALL...   992717
# 8           1  @AceofSpadesHQ My 8yo nephew is inconsolable. ...   664510
# 9           1  RT @paigetweedy: no offense… but like… how do ...   260471
# 10          1  RT @StephenSchlegel: she's thinking about how ...   295793
# 11          1  I do hope people who are vocal about climate c...   763719
# 12          2  RT @tveitdal: We only have a 5 percent chance ...   454673
# 13          1  RT @Alifaith55: Oh. My. God.\n\nTrump's Govern...    41161
# 14          2  Fossil fuel giant ExxonMobil ‘misled’ the publ...   658092
# 15          1  RT @GlblCtzn: 'I don't wanna live forever – an...   319524
# 16          1  RT @jackholmes0: Issues scrubbed from https://...   698009
# 17          1  RT @patagonia: If our elected leaders fail to ...   490604
# 18          1  RT @SenSanders: We have a president-elect who ...   228658
# 19          0  Calum: *tweets abt reunitingish w the cast*\n-...   547924

# %%
b = pd.read_csv('shifter_lexicon.csv')
## a lexicon of polairty shifters

# %%
b
# Out:
#         abandon  02232813  dobj
# 0       abandon    614907  dobj
# 1       abandon   2232523  dobj
# 2       abandon    615748  dobj
# 3       abandon   2080923  dobj
# 4         abate    245945  subj
# ...         ...       ...   ...
# 2214    wrap up    485823  dobj
# 2215      wreck   1568966  dobj
# 2216  write off   2483078  dobj
# 2217   yield up   2240331  dobj
# 2218        zap   1327970  dobj
#
# [2219 rows x 3 columns]

# %% [markdown]
# ## Test Model

# %%
df_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-711c74f5b217> in <module>
# ----> 1 df_test.head()
#
# NameError: name 'df_test' is not defined

# %%
d = pd.read_csv('Lsvc_test1.csv')
d
# Out:
#        tweetid  sentiment
# 0       169760          1
# 1        35326          1
# 2       224985          1
# 3       476263          1
# 4       872928          0
# ...        ...        ...
# 10541   895714          1
# 10542   875167          1
# 10543    78329          1
# 10544   867455          0
# 10545   470892          1
#
# [10546 rows x 2 columns]

# %% [markdown]
# ## Pipeline

# %% [markdown]
# 1. Run base model

# %% [markdown]
# ### Base Model

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn import svm

## from sklearn, we are importing all the necessary libraries we will be in need off
## for modelling,  model performance and feature exrraction

# %%
## more models to test being imported
from xgboost import XGBClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

# %%
from collections import Counter ## will be used to count the number of occurrances of each Part of speech
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer ## shorten words to its root according to the word's part of speech
from nltk.corpus import wordnet ## this library will allow us to find most similar word of a particular word

normalizer = WordNetLemmatizer()
def get_part_of_speech(word):
    probable_part_of_speech = wordnet.synsets(word) ## finding word that is most similar (synonyms) for semantic reasoning
    pos_counts = Counter() # instantiating our counter class
    
    ## finding part of speech of word if part of speech is either noun, verb, adjective etc and add it up in a list
    pos_counts["n"] = len(  [ item for item in probable_part_of_speech if item.pos()=="n"]  )
    pos_counts["v"] = len(  [ item for item in probable_part_of_speech if item.pos()=="v"]  )
    pos_counts["a"] = len(  [ item for item in probable_part_of_speech if item.pos()=="a"]  )
    pos_counts["r"] = len(  [ item for item in probable_part_of_speech if item.pos()=="r"]  )
    most_likely_part_of_speech = pos_counts.most_common(1)[0][0] ## will extract the most likely part of speech from the list
    return most_likely_part_of_speech

#def preprocess_text(text):
   # cleaned = re.sub(r'\W+', '', text).lower()
   # tokenized = word_tokenize(cleaned)
   # normalized = [normalizer.lemmatize(token, get_part_of_speech(token)) for token in tokenized if len(token) > 1]
   # return normalized

# %%
from nltk.tokenize import TweetTokenizer ## we will use this custome TweetTokenizer from nltk to tokenize our text
import string ## from the string class, we will use its built in methods to find punctuations and numeric tokens
punctuation= list(string.punctuation)

# %%
## negation
negations = ['aint', 'ain\'t', 'cannot', 'cant', 'can\'t', 'darent', 'didnt', 'didn\'t', 'doesn\'t',
'doesnt', 'dont', 'don\'t', 'hadnt', 'hadn\'t','hardly', 'hasnt', 'hasn\'t', 'havent', 'haven\'t', 'havnt', 'havn\'t',
 'isnt', 'isn\'t', 'lack', 'lacking', 'lacks', 'neither', 'never', 'no', 'nobody', 'none', 'nor', 'not', 
 'nothing', 'nowhere', 'mightnt', 'mustnt' , 'neednt', 'oughtnt', 'shant', 'shouldnt', 'wasnt', 'wasn\'t', 'shouldn\'t',
 'without', 'wouldnt', 'wouldn\'t', '*n’t', 'doesn’t', 'hasn’t', 'wouldn’t', 'shouldn’t', 'wasn’t', 'can’t',
 'don’t', 'didn’t', 'ain’t', 'don\'t', 'won\'t']
def negation(df):
    b = df
    for i in negations:
        if i in df:
            b =  re.sub(i, 'not', df)
    return b
            
### some words that exist in stopwords add to the semantic meaning of a sentence. We were going to use this list of negation words
## to add more semantic and consistent meaning to our tweets by turning each negation word to not. This slightly decreased
## model performance so we will not use it

# %%
#df['message'] = df['message'].apply(negation) ## neglect using negation

# %%
df['message'][86]
# Out:
# '#BeforetheFlood \nEVERYONE must watch this!! people must understand global warming is very real @LeoDiCaprio \nhttps://t.co/vTqnt1f6Ni'

# %%
## create a fiunction that cleans up tweets
def clean(df):
    df['token'] = df['message'].apply(TweetTokenizer().tokenize) ## first we tokenize
    df['punc'] = df['token'].apply(lambda x : [i for i in x if i not in punctuation]) ## remove punctuations
    df['dig'] = df['punc'].apply(lambda x: [i for i in x if i not in list(string.digits)]) ## remove digits
    df['final'] = df['dig'].apply(lambda x: [i for i in x if len(i) > 1]) ## since we not removing stopwords, remove all words with only 1 character
    df['final'] = df['final'].apply(lambda x: [normalizer.lemmatize(token, get_part_of_speech(token)) for token in x])
    ## lemmatize by way of applying part of speech
    return df['final']

# %%
df['final'] = clean(df)

# %%
df['final'][4] ## how our tweets look after the clean function is applied
# Out:
# ['RT',
#  '@SoyNovioDeTodas',
#  "It's",
#  '2016',
#  'and',
#  'racist',
#  'sexist',
#  'climate',
#  'change',
#  'deny',
#  'bigot',
#  'be',
#  'lead',
#  'in',
#  'the',
#  'poll',
#  '#ElectionNight']

# %%
X = df['final'] ## split dataframe into features and ground truth
y = df['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
## train test split. we find that a split size of 10% test data gives us the best performance

# %%
X_train = list(X_train.apply(' '.join)) ## create a single list of all tweets for both train and test features

# %%
X_test = list(X_test.apply(' '.join))

# %%
## how our test features looks like
X_train
# Out:
# ['Why do some people still doubt global warming https://t.co/bv7K6gFrgS https://t.co/CHxym9oAoD',
#  'RT @Trial_Watcher1 @DrMartyFox @SheriffClarke @LouDobbs @seanhannity the global warming scam to tax the air we breathe in order to fund',
#  'RT @NatGeoChannel Watch #BeforeTheFlood right here a @LeoDiCaprio travel the world to tackle climate change https://t.co/LkDehj3tNn httÃ',
#  'RT @Greenpeace What if climate change be just really big #AprilFools prank https://t.co/RKcZo4nNtf https://t.co/pUtpm0Dp4f',
#  "RT @emorwee In which casually speculate that Steve Bannotn knotws climate change will cause chaos and that's sorta what he want https://t…",
#  'RT @JasonLastname After war and climate change have kill u all just hope alien visit earth and ride our rollercoasters',
#  "not believe Bella Thorne's and Tyler Posey's relationship exist just a much a Donald Trump doesn't believe global warming do",
#  'RT @theecoheroes Fantastic Beasts Our secret weapon in combat man-made climate change animal #climatechange #animalsÃ',
#  'Largest all-female expedition brave Antarctica to fight inequality climate change LONDON Thomson Reuters https://t.co/80aFAKchfh',
#  'RT @guardian We not know that yet EPA head Scott Pruitt deny that carbon dioxide cause global warming',
#  'RT @FredKrupp BREAKING and breathtakingly wrong ): Pruitt say would not agree Co2 primary contributor to global warming https://t…',
#  "RT @ajplus Now you can plant tree and protest President Trump's climate change denial at the same time https://t.co/VmEMsnGl5J",
#  'RT @ClimateDepot Warmists upset Energy Secretary Rick Perry want to hold climate change debate https://t.co/lgesfX4c0I',
#  "RT @OFA The nation's top medical society say that man-made climate change be make Americans sick https://t.co/qE4356FAyj #ActOnClim",
#  "RT @1957AJB We knotck ourselves out over Brexit and Trump but think climate change will bury both of those issues-But really hope I'm",
#  'Good luck with that UN meet urge Ëœhighest political commitmentÃ on climate change https://t.co/RwlSX8fIUX',
#  "RT @FoxNews Macron My charm may have change Trump's mind on climate change https://t.co/HxDJQwgBE5 https://t.co/9iDj2a5NzQ",
#  "@LDrogosPhD I'd say it's because of climate change but not want to sound like conspiracy theorist to none believer of science",
#  'RT @BernieSanders The concept of global warming be create by and for the Chinese in order to make manufacture notn-competitiÃ',
#  'RT @feraliaga Is there link between climate change and diabetes https://t.co/dO5u5rKywu https://t.co/zH4Y9FyO1I',
#  "Bangladesh be particularly vulnerable to climate change but it people aren't helpless victim find Joseph Hanlo https://t.co/Sn0UFjD83E",
#  'RT VoiceboxOFNaija Discussion Abrupt climate change be here How do we prep for this ... brazil 11 netherlands https://t.co/sIFqd96stP',
#  'RT @phil_di_grange @SenatorMRoberts not offence but you spend year study global warming fraud and never model close of power plÃ',
#  'RT @zoeschlanger The https://t.co/O90Lo4IhlO climate change page all of them go https://t.co/addPexiIWo https://t.co/OFMHblVTZ7 http :/',
#  "RT @NPR Ahead of Earth Day April 22 @NPRGoatsandSoda want to knotw what you're ask about the effect of climate change https://t.co/…",
#  'Drought in southern Africa point to urgent need for climate change plan https://t.co/d4LTsIaQov',
#  'RT @Xerox way to counter climate change and well your business at the same time https://t.co/kpdVNR5pOz',
#  'RT @climatehawk1 New poster imagine national park in 2050 under #climate change not pretty @ClimateCentral',
#  'create more American job by put the coal industry back in business because climate change be apparently fake news',
#  'RT @LIBSRSCUM Not one of these climate change alarmist claim have ever come true https://t.co/ROS8KPNRlg',
#  'From @haqqmisra The time be ripe for isolationist elect official to take action on climate change https://t.co/qNyKRXmdFE',
#  'This MTV star flog climate change hypocrite Leonardo DiCaprio with ONE photo It should win award https://t.co/6mGDfCHBdS via @twitchyteam',
#  'Interview with Vladimir Rakhmanin on the role of sustainable food system in face climate change https://t.co/XMzgH92mIp #AGENDA21',
#  'RT @Dorofcalif GOP congressman God will take care of climate change if it exist https://t.co/K1NjJzZue8 via @HuffPostPolYO HAVE SOME',
#  'RT @peta Meat production be lead cause of climate change water waste deforestation extinction #WorldVeganDayÃ',
#  'RT @Alex_Verbeek RT if you agree All child schould be teach about #climate change They should read this',
#  "The earth have be here for billion of year human aren't cause global warming https://t.co/NRwb5QjpXp",
#  'RT @mrspanstreppon @bdylan234 @IvankaTrump In 10 Ivanka think climate change be joke https://t.co/hMbJ1WkW3w',
#  'Harry be type up strongly word email to management about the danger of global warming shortly',
#  'RT @SenSanders On virtually every major issue raise the minimum wage climate change pay equity for woman we be the majority',
#  '@__BranMan global warming always be an issue though',
#  "RT @sweetatertot2 In the 1970 the so call scientist be tell u the earth would freeze over notw it's global warming smh",
#  'RT @SenSanders We have president-elect who not believe in climate change Millions of people be go to have to say Mr TÃ',
#  'There have be not statistically significant global warming in about 17 year #climate',
#  'RT @democracynow @NaomiAKlein lot of journalist not want to politicize human catastrophe by talk about climate change',
#  'RT @SenatorDurbin Denying CO2 be the primary contributor to global warming be like deny gravity keep our foot on the grind it go',
#  'Five reason to be optimistic about climate change High Country News https://t.co/LiSlGcwZL8 #ClimateChange',
#  'RT @daveweigel The televise debate have more Qs about hack Clinton campaign email than about climate change https://t.co/UUPQ83e8Jq',
#  'RT @JebSanford Obama give Iran future with nuclear weapon Trump get out of the Paris Accord.Mindless liberal fear climate change more',
#  'RT @edyong209 How professional climate change denier discover the lie and decide to fight for science https://t.co/WFWbcudMRi',
#  '@realDonaldTrump Mr Trump not think you read me but you should take seriously the climate change issue do it for your son please',
#  'RT @DonCheadle Thanks to global warming Antarctica be start to turn green The Washington Post https://t.co/qLvJJkElwJ',
#  '@alexavellian @jkenney Cost of do not abt climate change point finger instead more than do something Grow pair man up',
#  "Scott Pruitt Fox News roast Donald Trump's EPA chief over climate change https://t.co/P1arfNmbFt Independent https://t.co/uAtycS7mvo",
#  'PolySciMajor EPA chief not think carbon dioxide be main cause of global warming and .. wait what https://t.co/yeLvcEFXkC via @mashable',
#  'RT @nytimes Air-conditioning create demand Then it contribute to climate change Which make u want air-condition more https://t.…',
#  'RT @BlaneDarlink @carloslcurbelo Thank you AND Floridians need you to speak out even more about sea level rise global warming not to',
#  'Warmist review Gore be climate change James Bond in urgent exhilarate Inconvenient Sequel https://t.co/6YVPlq9m1A #Eco #Green',
#  "RT @AltUSPressSec Thinking win single GA race mean you're on top be like think climate change isn't real because it snotwed once",
#  'RT @WorldfNature Oceans store up stagger amount of heat the memory of all of the past climate change Chicago Tribune',
#  "RT @insideclimate Here's reminder of what Exxon know about climate change from it own research and then try to deny",
#  'RT @TravelDudes Q4 via @SonjaSwissLife What type of travel activity do you believe contribute the most to climate change Give exampl',
#  'Geosciences Column Africas vulnerability to climate change #Geography https://t.co/N4GFuManCp https://t.co/vgkSAVTUra',
#  'RT @TeriAnne7201 Fake global warming at it fine #GlobalWarming #ElectricCars https://t.co/skVQFKbDhZ',
#  'RT @iansomerhalder Speaking of climate change-TONIGHT Is another killer episode of @YEARSofLIVING 10/9 on @NatGeoChannel https://t.co/TÃ¢â‚¬Â¦',
#  'RT @NYMag If elect Donald Trump would unleash catastrophic runaway climate change write @jonathanchait https://t.co/1gPnH8PTQs',
#  'RT @Stevenwhirsch99 Thankfully America have President that recognize Radical Islamic Terrorism be big threat than climate change',
#  'RT @RachelFeltman Kids notw have the right to sue the government over climate change Popular Science https://t.co/HCtcA1yjS4 via @PopSci',
#  "Here's how you can help make Congress tackle climate change https://t.co/4Jc3At4EKt",
#  '@candacesmith191 hey bunch of snowflake who not like global warming because snowflake melt under the slight bit of heat',
#  'RT @whereisdaz Imagine if people get a fire up about existential threat like climate change a they do about Facebook post',
#  'RT @jesscapo Thanks @grist for cover @EnviroDGI @ischool_TO #GuerrillaArchiving event to save climate change data',
#  'RT @AstroKatie If you be go to be single-issue voter not make global warming even bad would be good issue to choose https:/Ã¢â‚¬Â¦',
#  'RT @kemal_atlay Abandoned all pretense of take global warming seriously Hamilton exit Climate Change Authority blast PM https://t.…',
#  'RT @broadly This teen be inspire to stop climate change when her family farm be lose to flood https://t.co/GYqoyBeiih https://t.co/xim…',
#  '@realDonaldTrump threat climate action but some state vow to fight climate change since Trump not https://t.co/B13C3yrT1P #ActOnClimate',
#  "RT @CNN These be the six climate change policy expect to be target by Trump's executive order https://t.co/cTAwF6GLKx https://t.co/…",
#  'RT @nytimes Michael Bloomberg say city will fight climate change with or not Donald Trump https://t.co/U5UnOaO4WY https://t.c…',
#  "RT @faully33 Supreme Court loss create new problem for Adani's Australian mine Climate climate change news https://t.co/kfv1Ft7vLP",
#  'RT @TheRickyDavila Secretary Of Energy Rick Perry say he have not yet speak to trump about whether climate change be real or not This WH',
#  'RT @PeculiarBaptist Scott Pruitt be correct to question human activity a main cause of global warming Consensus argument be joke ht',
#  '@NewDay EPA Pruitt lie to congress about climate change Sessions lie about meet with Russia America be be take apart from inside',
#  'RT @YngLiberalGirl man who reject settle science on climate change should not lead the EPA https://t.co/VmaEKJGo6S',
#  'Next EPA chief do not believe in climate change align with coal industry https://t.co/RrhAAcdD8c cmts https://t.co/OtjATkqacO',
#  'RT @JoyAnnReid Theresa May accuse of be Donald Trump mole in Europe after UK try to water down EU climate change policy https://…',
#  'RT @ladailynews Report California need to address housing crisis to meet long-term climate change goal https://t.co/74H5Oj8K5j https://…',
#  "Trump say not really know if climate change be real The Washington Post error on safety side doesn't hurt https://t.co/NQYe5qBchK",
#  'RT @maggieNYT Clean air be vitally important Trump say about climate change Says he be keep an open mind',
#  'Chicago mayor Emanuel post EPA delete climate change page https://t.co/4ix3iwVGGm',
#  'RT @Ashley_L_Grapes #trump you promise to represent the people and we believe in climate change Please rethink your pick for EPA OurÃ',
#  'The global seed vault in Spitsbergen be threaten by climate change Piqd by #AndreaChu Article by @dpcarrington https://t.co/lcEhKMhvNU',
#  "RT @BillNye Ordering the EPA or NASA not to talk about climate change isn go to cool thing off Don't double down on deni",
#  'These photo force you to look the victim of climate change in the eye https://t.co/3UACtbToY1',
#  'climate change solution beneath our foot https://t.co/lKnY6q2Ob6 #climatechange #eco #environment #Sustainability',
#  "RT @Motofe We've have coal forever long before climate change what be do https://t.co/77R9YFbe1v",
#  '@JeffBezos when will @Amazon stop fund hate and climate change denial propaganda https://t.co/FeDRLybX03 @SierraRise #GrabYourWallet',
#  'Trump to annotunce decision on climate change Thursday https://t.co/8DHcsgw7vt https://t.co/0u2U1huE7q',
#  '@realDonaldTrump ought to consider global warming mitigation in infrastructure plan regardless cause rise tide call for sea wall',
#  'RT @griffin_klement There another story to tell about climate change And it start with water Judith Schwartz https://t.co/SEBebUXI…',
#  'Imagine actually not believe in climate change even China believe in climate change',
#  'RT @AP The Latest John Kerry say fail to fight climate change would be moral failure and betrayal https://t.co/4l9S2Itz4l',
#  "RT @mims About climate change Warming we're experience notw be due to CO2 emit in late 1970s Natural sink be sa",
#  '@SlFrexit @Scaramucci The guy be anti gun pro climate change marry Jewess trust reporter on his 1st day https://t.co/jdVP7rLeq8',
#  'RT @RyanMaue Just read through the study supposedly entirely refute Scott Pruitt on climate change Nope they actually confirm exactl',
#  'RT @PMOIndia We need to work together to create green world and mitigate the menace of climate change PM @narendramodi',
#  'RT @therightblue These expert say we have until 2020 to get climate change under control And they re the optimist https://t.co/bBzCJsH9…',
#  "RT @PoliticKels Don't worry about global warming We're go to build new Earth big Earth it will be the best Earth ever #TrumpNÃ",
#  "RT @robert_falkner Excellent piece by @martinwolf_ on why denial be America's predominant political response to climate change https://t.Ã¢â‚¬Â¦",
#  'RT @SnotxDick Just look at what climate change be do to our child @MaxineVVaters DO SOMETHING #INPeach https://t.co/at4phsKGTa',
#  'It be in the 90 in 1911 Does this mean global warming be slow down Lol https://t.co/6uk2KsLmbE',
#  'But but but ... global warming be cause blizzard Which 20yrs ago be call snotw https://t.co/nNIiZvGAW0',
#  '#notmypresident Trump abolish climate change in first moment of regime https://t.co/OB805FpZWx',
#  'SPORTS Tony Sopranot Look-a-Like find deny climate change at Los Angeles Zoo In hindsight could have do thing well',
#  'RT @ddlovato #IVotedBecause believe in equality we need comprehensive immigration reform be pro-choice and global warming IS real',
#  'Despite overwhelm evidence only 48 of Americans believe climate change be result of human activity https://t.co/ZYBf3cRRNn',
#  'RT @NBCNews The Terminator Arnotld Schwarzenegger and Pope Francis team up to talk about climate change',
#  'RT @nytimes How warming planet drive human migration https://t.co/c5fqrTpByh https://t.co/KG9ooXevf3',
#  'RT @capcbristol Will global warming impact on cold-related death Come to Prof Richard Morris Inaugural Lecture',
#  'RT @TREEAID Soil health be the key to tackle climate change and #foodsecurity Trees play big part in soil retention improv',
#  "RT @business Here's what President Trump's climate policy could mean for global warming https://t.co/6KOtQ6Lrve https://t.co/XlLQlEHbX1",
#  'EPA director-CO not primary contributor to climate change https://t.co/JsgXFRzXTn via @colorlines',
#  'RT @myRadioIntl Trump leave summit amid climate change trade dispute German leader cite unsatisfactory talk on cli ... http :/',
#  'RT @SenSanders On virtually every major issue raise the minimum wage climate change pay equity for woman we be the majority',
#  'RT @People4Bernie We be all Zach You and your friend will die of old age IÃ go to die from climate change https://t.co/r425dcmÃ¢â‚¬Â¦',
#  'RT @SenSanders We can win the war against climate change We can win the war in transform our energy system and can put million to wor',
#  'Trump tap climate change skeptic to oversee appointment of top NOAA official https://t.co/5ldTBDNyf5',
#  "RT @realDonaldTrump It's freeze outside where the hell be global warming",
#  'RT @ZEROCO2_ It might seem like an impossible task sometimes but this be how we can limit global warming to 1.5 https://t.co/aCkaqCaJDi…',
#  'Number one fully understand why her right notw we need global warming ve say if Ivanka weren my word',
#  "RT @davidaxelrod THAT's what everyone be talk about Not trade climate change refugee North Korea Syria ... they're talk",
#  'RT @Stormsaver reason not to completely despair about climate change in 2017 #climatechange #fossilfuels #zeroemissions',
#  'Who lead the world in the fight against climate change .. https://t.co/81FB3Rk3s2 #climatechange',
#  'RT @Laurie_David Imagine more than 250k march in street over concern about global warming @EPAScottPruitt say NOTHING @billmckibben',
#  'One of the most trouble idea about climate change just find new evidence in it favor https://t.co/KyyEynEZ1u',
#  'The case for #GeoEngineering climate change via @BjornLomborg https://t.co/lwCizbpQuj #Sustainability',
#  'Ifill do such good job in the 08 VP debate Pushed back against the notmalcy of Palin challenge Biden ask about climate change',
#  'RT @SaveLiberty1st Moore co-founder of Greenpeace say human be NOT to blame for global warming not scientific proof climate',
#  "RT @la__dee__da If you live in Miami and not believe in climate change there's something wrong with you Cough cough @tedcruz",
#  'RT @JustinTrudeau Welcome to Ottawa @Premier_Silver look forward to work together to fight climate change protect our envi',
#  'Top story China clarify for Trump uh no global warming be not Chinese hÃ https://t.co/27uxBahDY1 see more https://t.co/Tag4KXUhgE',
#  'RT @sarahlyonsinc There be not such thing a man make climate change Problem solve #StepsToReverseClimateChange https://t.co/LXq9vtEzVG',
#  'RT @swissmiss database of womenÃ right POC LGBT immigrant Muslim-American and climate change advocacy group https://t.co/tgcIvSÃ¢â‚¬Â¦',
#  "especially consider knotw how to solve the world's energy problem which will also aid in solve the climate change problem",
#  "RT @MorinToon Another kind of climate change We've go from long-term ecological consciousness to short-term greed #morintoon",
#  'Scorpio pisces need to stay faraway from each other a possible the red Sea might part global warming will stop',
#  "Europe have ton of money for global warming so it's time for them to pay for their own defense https://t.co/wUT1vW0MrV #MAGA",
#  'RT @SenSanders We have president-elect who not believe in climate change Millions of people be go to have to say Mr TÃ',
#  "RT @StephenSchlegel she's think about how she's go to die because your husband not believe in climate change https://t.co/SjoFoNÃ¢â‚¬Â¦",
#  "Euro Times For China climate change be not hoax it's business and political opportunity https://t.co/eztq1kNxCV via @moral_time",
#  'Trump Energy Department tell staff not to use phrase climate change via Geller Report Bravo . ... https://t.co/vfpD7lqcDA',
#  'RT @SenSanders We have president-elect who not believe in climate change Millions of people be go to have to say Mr TÃ',
#  '@SarahNourse @mattdurrer What be your thought on global warming #sarahmakethisvideo',
#  '@GlobalwarmJcp Humans be most definitely contribute to Globals warming There be few natural cause of global warming',
#  "RT @Pappiness @realDonaldTrump You're so smart that you think climate change be Chinese conspiracy",
#  'RT @RichardDawkins Harvey severity exacerbate by man-made climate change Chinese hoax https://t.co/KNImviTWtg The National Day of',
#  '@thehill Sure Dr Sanders proctologist-at-large knotws everything about climate change just ask him for his opinion bet it stink',
#  "RT @megancarpentier Oh hey remember when the transition team ask for name of climate change staff at DOE and women's program staff",
#  'Lord Stern climate change denier https://t.co/NyQlCnFKFg https://t.co/RYAlqcerPj',
#  'Court delay hand Trump victory over Obama climate change rule https://t.co/ZsfxA8ZBmo',
#  'RT @NiceTrumpTweets not deny climate change exist just not want to think about world where sunshine and rainbow not exist',
#  "RT @elakdawalla What's your cause Preventing climate change Improving public education Reforming govt regulation to be efficient and",
#  'African city must confront climate change https://t.co/lswAgGcZ0f',
#  '@SaltyoSweet network can be major reason .. but cold What happen to global warming',
#  'RT @davidsheen Israel forestry expert blame for fire climate change worst weather in 40 year bad choice to plant pin http',
#  'RT @nytopinion The physic of climate change cannot be reverse by calm negotiation https://t.co/L4wadshChU #NYTLetters',
#  "RT @sciencemagazine In this week's Editorial @Sir_David_King discus the role that innotvation must play in fight climate change",
#  'RT @SteveSGoddard If you still believe the global warming scam after read this post then you be an idiot https://t.co/Vo4w4r4DGL htt',
#  'RT @cynthix_ wanna cry my dad not believe in climate change',
#  "RT @Fusion Imagine if you will world where the medium cover climate change the way it cover Hillary Clinton's emailsÃ",
#  'RT @Anthony Basically not want public to hear about climate change https://t.co/TrQdNhBLux',
#  'Bloomberg Video Paris mayor tackle climate change with or not Trump https://t.co/u22Q3tb2Yb',
#  'RT @FoxNews March for Science rally take aim at climate change skepticism propose budget cut https://t.co/BIrr32OAm8',
#  '@hvysnow @LindaSuhler not believe in climate change but human be kill the planet with the pollution we create',
#  "RT @SueForMayor Investors worth 2.8 trillion be unite against Donald Trump's climate change denial https://t.co/wA9f0yIJKT",
#  'RT @MissAgneP 2010 me have the answer to ending global warming https://t.co/z5dyZwH92v',
#  'RT @BernieSanders The stake be enotmously high Literally in term of climate change the future of the planet be at stake https://t.cÃ¢â‚¬Â¦',
#  'RT @chulomang ppl who not believe in climate change try to explain all the hurricane https://t.co/qFvre7mxEF',
#  "Denying climate change be dangerous Join the push to the world's future His essay a WIRED guest editor",
#  "@PoliticusSarah @politicususa Time wakeup to the greed of the oil baron climate change Putin's sec.of state",
#  'RT @UNDPasiapac See how woman in #Myanmar #Cambodia be adapt to drought flood the impact of climate change #WorldWaterDay http',
#  "Chicago Mayor Rahm Emanuel revive EPA's delete climate change page on city website https://t.co/ZKYCk3cQPW",
#  'RT @Clara_k11 Remember when @realDonaldTrump say global warming be hoax create by the Chinese Well don it not',
#  "when ur enjoy the nice weather but at the same time knotw it's just bc of global warming https://t.co/ricLIB1Xkh",
#  'of Exxon climate change denier Rick Perry for head of Dept of energy The madness go on and on',
#  "RT @oldmudgie Oh note Beer quality threaten by global warming From December's Opening Times https://t.co/AGnNO4nc8V",
#  'RT @LastWeekTonight If you donÃ believe man-made global warming be silly issue give to the Natural Resources Defense Council http',
#  'RT @NWF warming planet mean rise in parasite heat stress for moose who be drop in number Join u to help',
#  'Reading the reply of people truly believe climate change be democrat propaganda https://t.co/2Al9Rd6Urx',
#  'RT @robinince Delingpole say liberal leave have lose the battle against climate change unaware that the acid sea not just flood thÃ',
#  "Liberals Don't trust data Clinton trust data look what happen to her Therefore climate change not real https://t.co/ic9sPPz7BA",
#  "RT @PSI_sustainable concise summary of climate change in California The plentiful rain snotw this year doesn't mean our water problem",
#  'rapidly grow human population and deteriorate health of our planet because of climate change and rise ... https://t.co/zhwucRkb4s',
#  "Talk about it when you believe in something especially climate change Because we need to knotw that we aren't alon https://t.co/CnbbASBUIT",
#  "RT @colbertlateshow Don't expect to hear the word climate change be toss around in the Trump Administration anymore #LSSC",
#  'RT @activist360 REPORT Rex Tillerson be investigate for use alias for email about link fossil fuel and climate change http',
#  'tweet FACTS about climate change be notw consider an act of defiance resistance but thank @BadlandsNPS @GoldenGateNPS @NASAClimate',
#  'RT @robertmcgillivr An intimate encounter with Polar Bear ... Stop global warming #Polarbear #globalwarming #seaice https://t.co/EAHHoyR…',
#  '12 report to read before the #climate summit Climate Home climate change news https://t.co/QsmVKv1T7k via @ClimateHome #ActOnClimate',
#  'ABC NBC CBS and Fox devote 2/3 less time to coverage of climate change in 2016 than they do in 2015 ABC ... https://t.co/mdnq5rcc7T',
#  'The Weather Channel shut down Breitbart Yes climate change be real https://t.co/5zxAFzrLSQ https://t.co/sHKr5SpQD3',
#  "RT @kylegriffin1 NYT review draft climate change rpt by feed scientist directly contradict the admin's global warming claim http",
#  'RT @chimichubs @todayarmyfights @BTSthe7legends record break health improve x100 global warming end salt rise more idea',
#  'RT @USFreedomArmy Now we knotw the real reason for the climate change hysteria Enlist with u at https://t.co/oSPeY3QMpH Join our pa',
#  "RT @StephenSchlegel she's think about how she's go to die because your husband not believe in climate change https://t.co/SjoFoNÃ¢â‚¬Â¦",
#  '@talha_s97 And dummy Donald #Trump keep on say that climate change be hoax',
#  "RT @nytimesbusiness Carbon capture technology could help fight global warming It may not survive Donald Trump's presidency https://t.co/…",
#  'RT @nytimesworld Scientists be point to an accomplice in China devastate smog crisis climate change https://t.co/7QpVo6a4Iw http',
#  'RT @CNN No snotw where there should be Bleached anemone Cracks in the ice This be what climate change look like',
#  'RT @HulkandTankGirl Now the DUP UDA be in power Tory vote may a well be vote for Trump climate change denial homophobic ... http',
#  'RT @bristanto8 if global warming not real then why do club penguin shut down',
#  'RT @Independent Leonardo DiCaprio give Ivanka Trump his climate change documentary in case her dad be still confuse https://t.co/EbQNUO…',
#  'RT @WePublicHealth Impacts of climate change in the Pacific region why the medical profession should speak up @HelenSzoke #iDEAConf ht',
#  'RT @bernielevv Just want to reiterate those for Trump be against climate change advancement woman minotity right for the prison iÃ',
#  'RT @RL_Miller Amy Goodman of @democracynow call out mainstream medium at #pplsummit for not cover climate change',
#  '@paulsacchi65 @nypost What do week ago snotw prediction have to do climate change',
#  'RT @ItsNickBean Umm global warming .. not hear of that not think that ummm what be that https://t.co/mjyWKKQoz8',
#  'RT @jennmperron This be so #Vermont love it Vermont nature diary document down-to-earth sign of climate change Boston Globe http :/',
#  'RT @MarketsTicker Pruitt not say if Trump believe climate change be real https://t.co/6zfpcMkTeB',
#  'The only good thing about global warming be that there will be less Florida to deal with',
#  'big question for this yearÃ climate change conference in Marrakesh https://t.co/plKYWUgryR',
#  '@TBSkyen global warming confirm a REAL in runeterra',
#  'Reader question science of climate change theory .. https://t.co/1zEco8Bwiv #climatechange',
#  'RT @arkmango bob morley be so soft ll bet he have dream of run in daisy with ellie and solve the climate change epidemic my beau',
#  "RT @savbrock It's almost 90 degree outside on Halloween and some of y'all be still deny the legitimacy of global warming",
#  'RT @estefania_dm Ironic how the country with the president who not believe in climate change be be hit with the most power hurrican',
#  'RT @stephblanc0 whoever think climate change be hoax must be the most ignotant person on this planet',
#  'Retweeted Nili Majumder @NiliMajumder ): No one govt can fight climate change alone not one government should ... https://t.co/VMsv8gArpI',
#  'RT @ClimateDepot New report about Antarctica be horrible news for global warming alarmist TheBlaze https://t.co/vAX4A7dRhl',
#  '2/2 Determined to salvage Obama legacy it draw battle line on immigration ObamaCare RACE RELATIONS and climate change ..',
#  'RT @BenWilhelm1230 Alt Tens of thousand of gullible fool who think man-made climate change be thing use fossil-fuel power vehi',
#  "RT @sean_spicier The nice part about nuclear arm race in the Middle East be we not be around to really experience climate change's wr",
#  'RT @NRDC Our new interactive map show how climate change impact your air quality https://t.co/Jt05qHuydN TAKE ACTION',
#  "RT @OsmundsenTerje Excellent from respect scientists'We can limit global warming to 1.5 if we do these thing the next 10 year htt",
#  'Regional Global seabird stress like climate change and plankton forage fish relocation be very hard to address at single site level 3/3',
#  'RT @LeftFootFwd They oppose abortion and gay marriage and not believe in climate change meet your new party of government',
#  'RT @changjaeftw this can end global warming https://t.co/reJTCU43DO',
#  'RT @mihirzaveri @ByKimMcGuire and explore whether climate change mean more big storm and what be or not be do about it',
#  'RT @AngrySalmond Among other bigotry the DUP be oppose to abortion gay marriage and homosexuality in general climate change and',
#  "If humanity wake up and survive climate change Trump's deserve legacy will be the exact opposite of his own delude sense of self",
#  "Dear Florida You're gonna be real piss when trump administration stop fight against global warming and you're the first one to goÃ Ëœâ",
#  'RT @WaterWired In @physorg_com New report summarize how climate change be affect water cycle in Germany https://t.co/U3WulvpJN8 tnx',
#  'RT @FareedZakaria ask @neiltyson for his take on climate change skeptic https://t.co/95AqLdtN6W Watch the full interview Sunday 10',
#  'wonder what @realDonaldTrump will do about climate change Hope he have lot of money to pay for lawyer Oops https://t.co/OaZVnKX0v1',
#  'RT @AmyAHarder Corporate America unite on climate change just a president oppose to action take office',
#  "RT @GeneticJen great deal of the data we have on climate change come from NASA and I'm genuinely worry about what the Trump administr",
#  '@JBHTD so you be climate change denier believe the climate scientist rather than climate denier cause they go https://t.co/oneKqsJs9j',
#  "Teens sue over climate change ask for Exxon's Wayne Tracker email Reuters #SmartNews https://t.co/f0yD5rIXZo",
#  'RT @haleemaaabbasi yeah because all the boy come on twitter to talk about global warming and climate change https://t.co/UGvZSpJO6S',
#  'RT @ProfAbelMendez Study reveal 82 percent of the core ecological process be notw affect by climate change https://t.co/ffzuwl5bWt htÃ',
#  'News from HBR The business world recognize the tremendous threat of climate change They need to make that perspeÃ https://t.co/7J8LDdmFvO',
#  'RT @richardbranson From UN reform to refugee conflict resolution to climate change inside the work of @TheEldersÃ',
#  'RT @caseycmill Great workshop on tie between racism and global climate change from @sustaininglife1 Interesting topic that be diÃ',
#  ...]

# %%
#linear svc
#text_clf = Pipeline([('tfidf', TfidfVectorizer(sublinear_tf=True, smooth_idf = True, max_df = 0.3, min_df = 5, token_pattern = r'\w{1,}', strip_accents = 'ascii', ngram_range = (1, 5))), ('clf', LinearSVC(C=0.8) )])
#Logistic
#text_clf = Pipeline([('tfidf', TfidfVectorizer(sublinear_tf=True, smooth_idf = True, max_df = 0.3, min_df = 5, token_pattern = r'\w{1,}', strip_accents = 'unicode', ngram_range = (1, 5))), ('clf', LogisticRegression(C = 2, max_iter = 1000, n_jobs=-1) )])
text_clf = Pipeline([('tfidf', TfidfVectorizer(sublinear_tf=True, smooth_idf = True, max_df = 0.3, min_df = 5, token_pattern = r'\w{1,}', strip_accents = 'ascii', ngram_range = (1, 5))), ('clf', svm.SVC(gamma = 100, C = 10) )])

## The fun part

## we built a model pipeline using a tf idf vectorize to weight each word token by its level of importance and vectorize it and using a
## radial basis function SVM to train our model.
## after a bit of hyperparamater tuning, we found these paramaters to work well. An aggressive max_df removes the most common occuring words
## in the corpus. This improves our model as by looking at bag of words in our EDA, most frequent words have very little semantic meaning
## a token pattern of alphanumeric words words out best and stripping all unicode accents also improves the model
## since our average tweets are 17 words, a ngram of 1 to 5 performes best in capturing semantic meaning

## the svm paramaters were chosen because the radial function does a better job at splitting up which areas the different semantic lies
## better than a linear SVC. The reason could be that our classification is not binary.

# %%
text_clf.fit(X_train, y_train) ## fit and train data
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=0.3, max_features=None,
#                                  min_df=5, ngram_range=(1, 5), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents='ascii',
#                                  sublinear_tf=True, token_pattern='\\w{1,}',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma=1,
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
predictions = text_clf.predict(X_test) ## make predictions on test set

# %%
print(confusion_matrix(y_test, predictions)) ## confusion matrix showing where true positives and false negatives
# Out:
# [[ 52  17  54   3]
#  [ 11  97 108   8]
#  [  5  30 810  50]
#  [  1   7  67 262]]

# %%
##after
print(classification_report(y_test, predictions)) ## here we are intrsted in the weighted f1 score
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.75      0.41      0.53       126
#            0       0.64      0.43      0.52       224
#            1       0.78      0.91      0.84       895
#            2       0.81      0.78      0.79       337
#
#     accuracy                           0.77      1582
#    macro avg       0.75      0.63      0.67      1582
# weighted avg       0.76      0.77      0.76      1582

# %%
##before
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.73      0.47      0.57       126
#            0       0.59      0.48      0.53       224
#            1       0.81      0.88      0.84       895
#            2       0.77      0.80      0.79       337
#
#     accuracy                           0.77      1582
#    macro avg       0.73      0.66      0.68      1582
# weighted avg       0.76      0.77      0.76      1582

# %% [markdown]
# ###### Notes
#
# ascii might work better as a strip accent

# %% [markdown]
# ### Test

# %% [markdown]
# #### clean test data

# %%
df_test = pd.read_csv('test.csv') ## load unseen test set

# %%
#df_test['message'] = df_test['message'].apply(negation)

# %%
df_test['final'] = clean(df_test) ## apply same feature cleaning as with the training set

# %%
df_test['final'] = list(df_test['final'].apply(' '.join)) ## create a list of our test set

# %% [markdown]
# ##### make predictions

# %%
df
# Out:
#        sentiment                                            message  tweetid  \
# 0              1  PolySciMajor EPA chief not think carbon dioxid...   625221
# 1              1  It's not like we lack evidence of anthropogeni...   126103
# 2              2  RT @RawStory: Researchers say we have three ye...   698562
# 3              1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4              1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# ...          ...                                                ...      ...
# 15814          1  RT @ezlusztig: They took down the material on ...    22001
# 15815          2  RT @washingtonpost: How climate change could b...    17856
# 15816          0  notiven: RT: nytimesworld :What does Trump act...   384248
# 15817         -1  RT @sara8smiles: Hey liberals the climate chan...   819732
# 15818          0  RT @Chet_Cannotn: .@kurteichenwald's 'climate ...   806319
#
#                                                    token  \
# 0      [PolySciMajor, EPA, chief, not, think, carbon,...
# 1      [It's, not, like, we, lack, evidence, of, anth...
# 2      [RT, @RawStory, :, Researchers, say, we, have,...
# 3      [#TodayinMaker, #, WIRED, :, 2016, was, a, piv...
# 4      [RT, @SoyNovioDeTodas, :, It's, 2016, ,, and, ...
# ...                                                  ...
# 15814  [RT, @ezlusztig, :, They, took, down, the, mat...
# 15815  [RT, @washingtonpost, :, How, climate, change,...
# 15816  [notiven, :, RT, :, nytimesworld, :, What, doe...
# 15817  [RT, @sara8smiles, :, Hey, liberals, the, clim...
# 15818  [RT, @Chet_Cannotn, :, ., @kurteichenwald, ', ...
#
#                                                     punc  \
# 0      [PolySciMajor, EPA, chief, not, think, carbon,...
# 1      [It's, not, like, we, lack, evidence, of, anth...
# 2      [RT, @RawStory, Researchers, say, we, have, th...
# 3      [#TodayinMaker, WIRED, 2016, was, a, pivotal, ...
# 4      [RT, @SoyNovioDeTodas, It's, 2016, and, a, rac...
# ...                                                  ...
# 15814  [RT, @ezlusztig, They, took, down, the, materi...
# 15815  [RT, @washingtonpost, How, climate, change, co...
# 15816  [notiven, RT, nytimesworld, What, does, Trump,...
# 15817  [RT, @sara8smiles, Hey, liberals, the, climate...
# 15818  [RT, @Chet_Cannotn, @kurteichenwald, s, climat...
#
#                                                      dig  \
# 0      [PolySciMajor, EPA, chief, not, think, carbon,...
# 1      [It's, not, like, we, lack, evidence, of, anth...
# 2      [RT, @RawStory, Researchers, say, we, have, th...
# 3      [#TodayinMaker, WIRED, 2016, was, a, pivotal, ...
# 4      [RT, @SoyNovioDeTodas, It's, 2016, and, a, rac...
# ...                                                  ...
# 15814  [RT, @ezlusztig, They, took, down, the, materi...
# 15815  [RT, @washingtonpost, How, climate, change, co...
# 15816  [notiven, RT, nytimesworld, What, does, Trump,...
# 15817  [RT, @sara8smiles, Hey, liberals, the, climate...
# 15818  [RT, @Chet_Cannotn, @kurteichenwald, s, climat...
#
#                                                    final
# 0      [PolySciMajor, EPA, chief, not, think, carbon,...
# 1      [It's, not, like, we, lack, evidence, of, anth...
# 2      [RT, @RawStory, Researchers, say, we, have, th...
# 3      [#TodayinMaker, WIRED, 2016, be, pivotal, year...
# 4      [RT, @SoyNovioDeTodas, It's, 2016, and, racist...
# ...                                                  ...
# 15814  [RT, @ezlusztig, They, take, down, the, materi...
# 15815  [RT, @washingtonpost, How, climate, change, co...
# 15816  [notiven, RT, nytimesworld, What, do, Trump, a...
# 15817  [RT, @sara8smiles, Hey, liberal, the, climate,...
# 15818  [RT, @Chet_Cannotn, @kurteichenwald, climate, ...
#
# [15819 rows x 7 columns]

# %%
test_predictions = text_clf.predict(df_test['final'])

# %%
test_predictions
# Out:
# array([1, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
df_test['sentiment'] = test_predictions

# %%
df_test['message'][28]
# Out:
# 'RT @insideclimate: Gov. Jerry Brown warns Trump that California not back down on climate change https://t.co/CO0p9PU3Fd'

# %%
df_test.drop(['message', 'token', 'punc', 'dig', 'final'], axis = 1, inplace=True)

# %%
df_test.to_csv('base.csv', index=False)

# %%
d = pd.read_csv('base.csv')

# %%
d['sentiment'].value_counts()
# Out:
#  1    6717
#  2    2357
#  0    1008
# -1     464
# Name: sentiment, dtype: int64
